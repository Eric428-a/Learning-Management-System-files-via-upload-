# %% [markdown]
# **EXPLANATORY DATA ANALYSIS AND SOME POSSIBLE TASKS FROM THE DATASET**

# %% [markdown]
# # <span style="color:darkblue;">**Adult_train_csv dataset EDA and Some Possible Tasks**</span>
#
# ---
#
# ### <span style="color:darkgreen;">**Project Overview**</span>
#
# The objective of this project is to conduct Exploratory Data Analysis (EDA) on the `adult_train.csv` dataset. This dataset includes various features related to demographic and work-related attributes, with the aim of analyzing patterns and relationships in the data. Additionally, a series of possible tasks based on this dataset will be explored, such as demographic, marital status, occupation, education, and gender analysis in relation to income.
#
# ---
#
# ### <span style="color:darkgreen;">**Steps Involved**</span>
#
# 1. **Import Necessary Libraries**
#    - Libraries such as `pandas`, `numpy`, `matplotlib`, and `seaborn` are imported to handle data manipulation, mathematical operations, and visualizations.
#
# 2. **Load the Data**
#    - The dataset `adult_train.csv` is loaded into a pandas DataFrame for easy manipulation and analysis.
#
# 3. **Inspect the Data**
#    - The structure of the dataset is examined using `.head()`, `.info()`, and `.describe()` to get a glimpse of the initial rows, data types, missing values, and statistical summaries of numerical columns.
#
# 4. **Check for Missing Values**
#    - Missing values can negatively impact analysis. A count of missing values in each column is generated to understand where data is lacking.
#
# 5. **Handle Missing Values (Optional)**
#    - If missing values are present, they are handled by filling numerical columns with their mean values.
#
# 6. **Check for Duplicate Values**
#    - Duplicate rows can affect the analysis results. The dataset is checked for duplicated entries, and duplicates are removed if necessary.
#
# 7. **Visualize the Data**
#    - Data visualization techniques such as histograms and count plots are used to explore the distribution of both numerical and categorical variables.
#
# 8. **Check Data Distribution**
#    - A global view of the data distribution is achieved through histograms, helping identify skewness or outliers.
#
# 9. **Check Correlations**
#    - The relationships between variables are explored using a correlation matrix heatmap, which helps identify highly correlated features.
#
# 10. **Handle Categorical Variables (Optional)**
#     - Categorical features are encoded into dummy variables to prepare them for model building.
#
# 11. **Outlier Detection (Optional)**
#     - Outliers are detected and removed using the Interquartile Range (IQR) method to ensure they don’t skew the analysis.
#
# 12. **Feature Scaling (Optional)**
#     - Numerical features are scaled using `StandardScaler` to bring them to a standard scale for machine learning purposes.
#
# ---
#
# ### <span style="color:darkgreen;">**Demographic Analysis and Visualizations**</span>
#
# - **Age Distribution**:
#   - A histogram with a KDE plot is used to analyze the distribution of ages across the dataset.
#
# - **Marital Status Analysis**:
#   - A count plot visualizes the distribution of marital statuses, especially focusing on those who are married and their income levels.
#
# - **Occupation Analysis**:
#   - A box plot is created to observe how the `Exec-managerial` occupation correlates with income levels, specifically targeting those earning more than 50K.
#
# - **Education Level and Income**:
#   - The relationship between different education levels (e.g., `Bachelors`) and income is explored through a box plot.
#
# - **Gender Disparities in Income**:
#   - Gender and income disparities are visualized, focusing on the income distribution for males versus females.
#
# - **Work Hours and Income**:
#   - A scatter plot is used to investigate how the number of hours worked per week influences income levels.
#
# - **Country of Origin and Income**:
#   - The distribution of income based on the country of origin, with a focus on the United States, is displayed via a box plot.
#
# ---
#
# ### <span style="color:darkgreen;">**Key Notes on the EDA Process**</span>
#
# 1. **Importance of Handling Missing and Duplicate Values**:
#    - Missing and duplicate data can skew the analysis and lead to misleading results. It is crucial to handle these anomalies before proceeding with further analysis.
#
# 2. **Outliers and Their Impact**:
#    - Outliers can significantly distort the understanding of relationships between variables. Detecting and removing outliers ensures that analysis remains accurate and reliable.
#
# 3. **Correlation and Multicollinearity**:
#    - Understanding correlations between features helps in feature selection and detecting multicollinearity, which can hinder the performance of certain machine learning models.
#
# 4. **Categorical Encoding**:
#    - Categorical variables must be transformed into numerical forms (like one-hot encoding) to be used in machine learning models. Proper encoding ensures the model correctly interprets the categorical data.
#
# 5. **Feature Scaling**:
#    - Feature scaling brings numerical variables to a common scale, which is essential for algorithms sensitive to the magnitude of features, such as distance-based models.
#
# ---
#
# ### <span style="color:darkgreen;">**Conclusion**</span>
#
# This project successfully provides a comprehensive EDA on the `adult_train.csv` dataset, offering insights into data distribution, potential outliers, and relationships between variables. The analysis is extended to demographic features like marital status, occupation, education, gender, and work hours to uncover trends related to income. Finally, the project outlines essential data preprocessing techniques such as handling missing values, removing duplicates, encoding categorical variables, and scaling features, all of which are crucial for accurate data analysis and model building.

# %% [markdown]
# # <span style="color:blue">**Step 1: Import Necessary Libraries**</span>
#
# In this step, we are importing several Python libraries that are essential for our analysis:
#
# - **Pandas**: A powerful library used for data manipulation and analysis, especially for working with structured data such as DataFrames.
# - **NumPy**: Provides support for arrays and matrices, along with a large collection of mathematical functions to operate on these data structures.
# - **Matplotlib**: This is the core Python library used for creating static, interactive, and animated visualizations. It's particularly useful for plotting data in various formats.
# - **Seaborn**: A statistical data visualization library built on top of Matplotlib, which offers enhanced data visualization tools, including heatmaps and complex plots.
#
# These libraries will allow us to load, manipulate, and visualize our dataset for a comprehensive analysis.

# %%
# Step 1: Import Necessary Libraries
# We need to import certain libraries that will help us analyze and visualize our data.

# %%
import pandas as pd  # This library helps us work with data in a tabular format.

# %%
import numpy as np  # This library provides support for mathematical operations.

# %%
import matplotlib.pyplot as plt  # This library helps us create visualizations like plots and charts.

# %%
import seaborn as sns  # Seaborn is a library built on top of Matplotlib for statistical data visualization.

# %% [markdown]
# # <span style="color:blue">**Step 2: Load the Data**</span>
#
# In this step, we load the dataset into a Pandas DataFrame, which is a two-dimensional labeled data structure (similar to a table in a database or Excel). The dataset is assumed to be in CSV format. Loading the dataset into a DataFrame allows us to perform various operations such as cleaning, transforming, and analyzing the data efficiently.

# %%
# Step 2: Load the Data
# Now, we will load our dataset into a DataFrame. A DataFrame is like a table where we can store and manipulate our data.
# We assume our data is in a CSV file named 'adult_train.csv'.

# %%
df = pd.read_csv('/content/adult_train.csv (1).csv')

# %% [markdown]
# # <span style="color:blue">**Step 3: Inspect the Data**</span>
#
# Here, we perform an initial exploration of the dataset:
#
# - **`df.head()`**: This function displays the first few rows of the dataset to give us a glimpse of the structure and content of the data.
# - **`df.info()`**: Provides a concise summary of the DataFrame, showing data types, non-null counts, and memory usage. This helps us understand the type of data we are dealing with and if there are any missing values.
# - **`df.describe()`**: Generates descriptive statistics for numerical columns, such as mean, standard deviation, and quartile values, which give us an understanding of the distribution of the numerical features.

# %%
# Step 3: Inspect the Data
# Let's take a quick look at our data to understand its structure and content.

# %%
print("First few rows of the dataset:")
# Out:
# First few rows of the dataset:

# %%
print(df.head())  # This command shows us the first few rows of our DataFrame.
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
print("\nSummary information about the dataset:")
# Out:
# Summary information about the dataset:

# %%
print(df.info())  # This command gives us an overview of the data types and missing values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   Workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education_Num   32561 non-null  int64
#  5   Martial_Status  32561 non-null  object
#  6   Occupation      30718 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Race            32561 non-null  object
#  9   Sex             32561 non-null  object
#  10  Capital_Gain    32561 non-null  int64
#  11  Capital_Loss    32561 non-null  int64
#  12  Hours_per_week  32561 non-null  int64
#  13  Country         31978 non-null  object
#  14  Target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
print("\nStatistical summary of numerical features:")
# Out:
# Statistical summary of numerical features:

# %%
print(df.describe())  # This command provides summary statistics for numerical columns.
# Out:
#                 Age        fnlwgt  Education_Num  Capital_Gain  Capital_Loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # <span style="color:blue">**Step 4: Check for Missing Values**</span>
#
# In this step, we check for missing values in the dataset using **`df.isnull().sum()`**. Missing data can negatively impact our analysis, and identifying which columns have missing values is essential for deciding how to handle them. Missing values may require imputation, removal, or other strategies depending on the nature of the data.

# %%
# Step 4: Check for Missing Values
# Missing values can affect our analysis, so we need to check if there are any.

# %%
print("\nNumber of missing values in each column:")
# Out:
# Number of missing values in each column:

# %%
print(df.isnull().sum())  # This command counts the missing values in each column.
# Out:
# Age                  0
# Workclass         1836
# fnlwgt               0
# Education            0
# Education_Num        0
# Martial_Status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_Gain         0
# Capital_Loss         0
# Hours_per_week       0
# Country            583
# Target               0
# dtype: int64

# %% [markdown]
# # <span style="color:blue">**Step 5: Handle Missing Values**</span>
#
# In this optional step, we handle the missing values:
#
# - **Numerical columns**: Missing values are filled using the column's mean, which is a common approach when data is assumed to be normally distributed.
# - **`df.fillna()`**: This function allows us to replace missing values. In this case, we are filling missing values for numeric columns with the mean values using the `inplace=True` parameter to modify the DataFrame directly.

# %%
# Step 5: Handle Missing Values (optional step)
# Depending on our analysis, we might decide to fill in missing values or drop rows with missing values.

# %%
# For numerical columns, we can fill missing values with the mean.
df.fillna(df.mean(numeric_only=True), inplace=True)

# %% [markdown]
# # <span style="color:blue">**Step 6: Check for Duplicate Values**</span>
#
# Duplicate rows can skew our analysis and provide misleading insights. In this step, we check for any duplicate rows using **`df.duplicated().sum()`**, which counts the number of duplicates in the DataFrame. Removing duplicates ensures that each observation is unique and does not bias the results.

# %%
# Step 6: Check for Duplicate Values
# Duplicate rows can skew our analysis, so we need to check for and remove them if necessary.

# %%
print("\nNumber of duplicate rows:")
# Out:
# Number of duplicate rows:

# %%
print(df.duplicated().sum())  # This command counts the duplicate rows in the DataFrame.
# Out:
# 24

# %% [markdown]
# # <span style="color:blue">**Step 7: Remove Duplicate Values**</span>
#
# Here, we remove any duplicate rows using the **`df.drop_duplicates()`** function. This operation is performed in place, meaning that the changes are applied directly to the DataFrame. Removing duplicates ensures a cleaner dataset for analysis.

# %%
# Step 7: Remove Duplicate Values (optional step)
# We remove duplicate rows to ensure each observation is unique and doesn't affect our analysis.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # <span style="color:blue">**Step 8: Visualize the Data**</span>
#
# Visualizing the data helps us understand the distributions of various features. In this step, we use Seaborn's **`countplot()`** for categorical columns to display the frequency of each category. For numerical columns, we use **`histplot()`** with kernel density estimation (KDE) to visualize the distribution of the data.
#
# This step provides an overview of how the data is distributed, which is useful for identifying patterns and trends.

# %%
# Step 8: Visualize the Data
# Visualizing the data helps us understand its distribution and identify patterns.
# We create histograms with kernel density estimation curves for numerical features.
# And bar plots for categorical features to see the distribution of different categories.

# %%
for column in df.columns:
    if df[column].dtype == 'object':  # Check if the column is categorical
        sns.countplot(y=column, data=df)
        plt.title(f"Distribution of {column}")
        plt.show()
    else:
        sns.histplot(df[column], kde=True)
        plt.title(f"Distribution of {column}")
        plt.show()

# %% [markdown]
# # <span style="color:blue">**Step 9: Check Data Distribution**</span>
#
# Here, we generate histograms for all numerical features using **`df.hist()`** to visualize the distribution of data in each column. This step is essential for spotting skewness or outliers in the data. The histograms help us understand the spread and shape of the data, which informs subsequent analysis decisions.

# %%
# Step 9: Check Data Distribution
# We visualize the distribution of data in each column to identify any skewness or outliers.

# %%
df.hist(bins=30, figsize=(20,15), density=True)
plt.show()

# %% [markdown]
# # <span style="color:blue">**Step 10: Check Correlations**</span>
#
# In this step, we create a correlation matrix heatmap using **`sns.heatmap()`** to identify relationships between numerical variables. Correlation coefficients range from -1 to +1, with values closer to +1 or -1 indicating a strong linear relationship. Visualizing correlations can help us understand how different features interact and whether any multicollinearity exists.

# %%
# Step 10: Check Correlations
# Checking correlations helps us understand the relationships between different variables.
# We create a correlation matrix heatmap to visualize these relationships.

# %%
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Matrix")
plt.show()
# Out:
# <ipython-input-39-0e91bf66e822>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# # <span style="color:blue">**Step 11: Handle Categorical Variables**</span>
#
# Categorical variables need to be encoded as numerical values for most machine learning algorithms. In this step, we use **`pd.get_dummies()`** to convert categorical variables into dummy/indicator variables. This process transforms categories into binary columns, making them suitable for analysis while avoiding the introduction of bias due to numerical ordering.

# %%
# Step 11: Handle Categorical Variables (optional step)
# If our data contains categorical variables, we might need to encode them into numerical values.

# %%
df = pd.get_dummies(df, drop_first=True)  # Convert categorical variables into dummy/indicator variables.

# %% [markdown]
# # <span style="color:blue">**Step 12: Outlier Detection**</span>
#
# Outliers can distort the results of our analysis. In this step, we detect and remove outliers using the **Interquartile Range (IQR)** method. The IQR represents the middle 50% of the data, and values outside the range [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR] are considered outliers. Removing these values helps prevent skewed results.

# %%
# Step 12: Outlier Detection (optional step)
# Outliers can significantly affect our analysis, so we use methods like IQR score or Z-score to detect and handle them.

# %%
Q1 = df.quantile(0.25)

# %%
Q3 = df.quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]  # Remove outliers.

# %% [markdown]
# # <span style="color:blue">**Step 13: Feature Scaling**</span>
#
# In this step, we scale the features using **`StandardScaler()`**, which standardizes the data by removing the mean and scaling to unit variance. This is especially important when features have different ranges, as it ensures that all features contribute equally to the model. Standardization is a crucial preprocessing step for many machine learning algorithms.

# %%
# Step 13: Feature Scaling (optional step)
# If our dataset contains features with different scales, we might need to scale them to a standard scale.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)  # Scale the features to a standard scale.

# %% [markdown]
# **POSSIBLE TASKS FROM THE DATASET**

# %% [markdown]
# # <span style="color:purple">**Demographic Analysis**</span>
#
# Explore the demographic distribution of the dataset to understand the population composition.
#
# ## <span style="color:purple">Age Distribution</span>
# Analyze the age distribution to assess how age varies within the dataset.

# %%
# Demographic Analysis: Explore the demographic distribution of the dataset

# %%
# Age Distribution

# %%
sns.histplot(df['Age'], bins=20, kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # <span style="color:teal">**Marital Status Analysis**</span>
#
# Investigate how marital status affects income levels to understand potential disparities.
#
# ## <span style="color:teal">Marital Status Distribution</span>
# Examine the distribution of marital statuses within the dataset.

# %%
# Marital Status Analysis: Investigate how marital status affects income levels

# %%
sns.countplot(y='Martial_Status_ Married-civ-spouse', data=df, order=df['Martial_Status_ Married-civ-spouse'].value_counts().index)
plt.title("Marital Status Distribution")
plt.xlabel("Count")
plt.ylabel("Marital Status")
plt.show()

# %% [markdown]
# # <span style="color:brown">**Occupation Analysis**</span>
#
# Investigate the distribution of occupations and their corresponding incomes to determine economic disparities among job types.
#
# ## <span style="color:brown">Occupation vs Income</span>
# Analyze how different occupations relate to income levels.

# %%
# Occupation Analysis: Investigate the distribution of occupations and their corresponding incomes

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Occupation_ Exec-managerial', y='Target_ >50K', data=df)
plt.title("Occupation (Exec-managerial) vs Income")
plt.xlabel("Occupation (Exec-managerial)")
plt.ylabel("Income (>50K)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # <span style="color:navy">**Education Analysis**</span>
#
# Analyze the relationship between education level and income to assess how education influences earnings.
#
# ## <span style="color:navy">Education Level vs Income</span>
# Examine how educational attainment relates to income levels.

# %%
# Education Analysis: Analyze the relationship between education level and income

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Education_ Bachelors', y='Target_ >50K', data=df)
plt.title("Education Level vs Income")
plt.xlabel("Education Level (Bachelors)")
plt.ylabel("Income (>50K)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # <span style="color:darkgreen">**Gender Analysis**</span>
#
# Investigate any gender disparities in income within the dataset to understand gender-related income gaps.
#
# ## <span style="color:darkgreen">Gender vs Income</span>
# Analyze how gender influences income levels.

# %%
# Gender Analysis: Investigate any gender disparities in income within the dataset

# %%
sns.boxplot(x='Sex_ Male', y='Target_ >50K', data=df)
plt.title("Gender vs Income")
plt.xlabel("Gender (Male)")
plt.ylabel("Income (>50K)")
plt.show()

# %% [markdown]
# # <span style="color:indigo">**Work Hours Analysis**</span>
#
# Explore the relationship between the number of hours worked per week and income to assess potential correlations.
#
# ## <span style="color:indigo">Hours per Week vs Income</span>
# Investigate how weekly working hours correlate with income levels.

# %%
# Work Hours Analysis: Explore the relationship between the number of hours worked per week and income

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Hours_per_week', y='Target_ >50K', data=df)
plt.title("Hours per Week vs Income")
plt.xlabel("Hours per Week")
plt.ylabel("Income (>50K)")
plt.show()

# %% [markdown]
# # <span style="color:crimson">**Country of Origin Analysis**</span>
#
# Analyze how the country of origin affects income levels to identify geographic disparities.
#
# ## <span style="color:crimson">Country vs Income</span>
# Examine the influence of nationality on income levels.

# %%
# Country of Origin Analysis: Analyze how the country of origin of individuals affects their income levels

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Country_ United-States', y='Target_ >50K', data=df)
plt.title("Country vs Income")
plt.xlabel("Country (United-States)")
plt.ylabel("Income (>50K)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # <span style="color:darkorange">**Final Analysis of Marital Status vs Income**</span>
#
# Reassess how marital status affects income levels to confirm previous findings.
#
# ## <span style="color:darkorange">Marital Status vs Income (Re-evaluation)</span>
# Analyze income differences based on marital status again for comprehensive insights.

# %%
# Marital Status Analysis: Investigate how marital status affects income levels

# %%
sns.boxplot(x='Martial_Status_ Married-civ-spouse', y='Target_ >50K', data=df)
plt.title("Marital Status vs Income")
plt.xlabel("Marital Status (Married-civ-spouse)")
plt.ylabel("Income (>50K)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # <span style="color:darkblue">**Conclusion**</span>
#
# In this project, we conducted a thorough **Exploratory Data Analysis (EDA)** on the dataset, which included various steps aimed at understanding the underlying patterns and relationships among different variables. The key steps and findings are summarized below:
#
# ## <span style="color:darkgreen">**Data Preparation and Cleaning**</span>
# - We began by importing essential libraries such as **Pandas**, **NumPy**, **Matplotlib**, and **Seaborn** to facilitate data manipulation and visualization.
# - The dataset was loaded and inspected for structure, summary statistics, and missing values. Steps were taken to handle any missing or duplicate data to ensure the integrity of our analysis.
# - We transformed categorical variables into numerical values and identified and removed outliers that could skew the results. Feature scaling was also performed to normalize the data for more accurate analysis.
#
# ## <span style="color:darkgreen">**Data Visualization and Analysis**</span>
# - A series of visualizations were created to explore demographic factors affecting income. These included histograms and box plots that revealed significant trends:
#   - **Age Distribution**: Indicated variations in income across different age groups.
#   - **Marital Status**: Showed a clear correlation between marital status and income levels, with married individuals generally earning more.
#   - **Occupation and Education**: Both factors were found to significantly influence income, highlighting economic disparities based on job type and educational attainment.
#   - **Gender Disparities**: The analysis underscored persistent income gaps between genders, pointing to systemic issues that may need addressing.
#   - **Work Hours**: A positive correlation was observed between hours worked per week and income, suggesting that higher labor input typically results in greater earnings.
#   - **Country of Origin**: Income levels varied by country, reflecting the impact of geographic economic conditions on individual earnings.
#
# ## <span style="color:darkgreen">**Insights and Implications**</span>
# - The findings from this analysis emphasize the complex interplay of demographic factors in determining income.
# - They highlight the need for targeted interventions and policies aimed at addressing income inequality based on marital status, education, and gender.
# - Future analyses could delve deeper into additional variables and employ predictive modeling to forecast income based on the identified factors.
#
# In conclusion, this EDA serves as a foundational step towards understanding the multifaceted issues surrounding income distribution and the socioeconomic factors that contribute to it. The insights gained can inform both policy decisions and further research endeavors.
