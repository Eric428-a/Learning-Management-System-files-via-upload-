# %% [markdown]
# # <span style="color:#1f77b4">1.5.3. Momentum Trading Strategy</span>
#
# ## <span style="color:#ff7f0e">Project Overview</span>
#
# This project delves into the development and implementation of a **momentum trading strategy** using historical cryptocurrency data. Momentum trading is a strategy that seeks to capitalize on the continuation of existing trends in the market. By analyzing past price movements and trading volumes, we aim to generate trading signals that help in making informed buy or sell decisions.
#
# ## <span style="color:#2ca02c">Objectives</span>
#
# The key objectives of this project are:
#
# - **Historical Data Analysis**: Analyze and visualize historical cryptocurrency data to understand market trends and behavior.
# - **Outlier Detection and Handling**: Identify and address anomalies in the dataset to ensure the integrity of the analysis.
# - **Feature Engineering**: Extract and create significant features, such as momentum indicators and moving averages, that are critical for developing trading strategies.
# - **Trading Signal Development**: Formulate trading signals based on momentum indicators to guide trading decisions.
# - **Strategy Evaluation**: Visualize the effectiveness of the trading strategy through various plots and charts, and assess its performance.
#
# ## <span style="color:#d62728">Dataset</span>
#
# - **File Path**: `/content/coin_CryptocomCoin.csv`
# - **Description**: The dataset contains historical price and volume data for a cryptocurrency. It includes various columns that provide insights into the market’s historical behavior.
# - **Columns**:
#   - **Date**: The date of the record.
#   - **High**: The highest price recorded on the given date.
#   - **Low**: The lowest price recorded on the given date.
#   - **Open**: The opening price on the given date.
#   - **Close**: The closing price on the given date.
#   - **Volume**: The total trading volume on the given date.
#   - **Marketcap**: The market capitalization on the given date.
#
# ## <span style="color:#9467bd">Steps Involved</span>
#
# ### 1. Data Loading and Exploration
#
# - **Loading Data**: Import the dataset using `pandas` and read the CSV file into a DataFrame.
# - **Initial Exploration**: Display the first few rows and summary statistics to get a basic understanding of the data structure and its distribution.
# - **Missing Values**: Check for missing values in each column and handle them appropriately if any are found.
#
# ### 2. Feature Engineering
#
# - **Date Conversion**: Convert the 'Date' column to a `datetime` format to facilitate time-based operations and analysis.
# - **Feature Extraction**:
#   - **Year**: Extract the year from the 'Date' column.
#   - **Month**: Extract the month from the 'Date' column.
#   - **Day**: Extract the day from the 'Date' column.
#
# ### 3. Data Visualization
#
# - **High and Low Prices Over Time**: Plot the high and low prices over time to visualize the price fluctuations.
# - **Volume of Trades Over Time**: Plot trading volumes over time to understand trading activity.
# - **Market Capitalization Over Time**: Plot market capitalization to observe its trend over the analyzed period.
#
# ### 4. Preprocessing
#
# - **Drop Irrelevant Columns**: Remove columns that do not contribute to the analysis, such as 'SNo', 'Name', and 'Symbol'.
# - **Handle Missing Values**: Confirm that there are no missing values in the dataset, as noted in the exploration phase.
# - **Outlier Detection and Removal**:
#   - **IQR Method**: Implement the Interquartile Range (IQR) method to detect and remove outliers from numerical columns ('High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap').
# - **Feature Scaling**: Apply `StandardScaler` to scale numerical features, ensuring they contribute equally to the analysis.
#
# ### 5. Momentum Indicator Calculation
#
# - **Define Momentum**: Calculate momentum indicators based on historical price changes over specified periods.
# - **Periods**: Compute momentum for various periods (90, 180, 270, and 360 days).
# - **Create Columns**: Add new columns to the dataset to store momentum values for each period.
#
# ### 6. Trading Signals
#
# - **Signal Generation**: Develop trading signals based on the momentum indicators.
#   - **Buy Signal**: Generate a buy signal when the momentum is positive.
#   - **Sell Signal**: Generate a sell signal when the momentum is negative.
# - **Visualization**: Plot the buy and sell signals along with closing prices to visualize trading decisions.
#
# ### 7. MACD Indicator Calculation
#
# - **MACD Calculation**: Compute the Moving Average Convergence Divergence (MACD) indicator using the Exponential Moving Averages (EMAs) for 12-day and 26-day periods.
# - **Signal Line**: Calculate the Signal line (9-day EMA of MACD) to aid in trading decisions.
#
# ### 8. Final Visualization
#
# - **MACD and Signal Line Plot**: Plot the MACD and Signal line to observe their behavior and potential trading signals.
# - **Final Dataset Display**: Present the dataset with all calculated indicators and signals to review the final output.
#
# ## <span style="color:#8c564b">Conclusion</span>
#
# The project successfully implements a momentum trading strategy using historical cryptocurrency data. By analyzing price trends and trading volumes, and computing various technical indicators, the project aims to generate actionable trading signals. The strategy leverages both momentum indicators and MACD to make informed trading decisions.
#
# Through visualizations and analysis, the project demonstrates how momentum trading can be applied to cryptocurrency markets to potentially improve trading outcomes.
#
# ## <span style="color:#e377c2">Next Steps</span>
#
# - **Strategy Optimization**: Explore further optimization of trading signals and strategies to enhance performance.
# - **Backtesting**: Conduct backtesting using historical data to evaluate the strategy's effectiveness and refine it.
# - **Real-time Integration**: Consider integrating the strategy with real-time data for live trading applications and monitoring.

# %% [markdown]
# ## <span style="color:#1f77b4">1. Importing Libraries</span>
#
# In this step, we import essential libraries required for data manipulation, visualization, and analysis. Each library serves a specific purpose in the project:
#
# ### <span style="color:#ff7f0e">1.1. Pandas</span>
#
# - **Library**: `pandas`
# - **Purpose**: Provides data structures and functions needed to manipulate structured data. It is used for reading and handling the dataset, performing data cleaning, and conducting exploratory data analysis (EDA).
# - **Function**: `import pandas as pd`
# - **Example Usage**: `data = pd.read_csv(file_path)` reads the CSV file into a DataFrame, allowing for further data operations.
#
# ### <span style="color:#2ca02c">1.2. NumPy</span>
#
# - **Library**: `numpy`
# - **Purpose**: Offers support for numerical operations and mathematical functions. It is used for array operations and calculations necessary for data analysis and preprocessing.
# - **Function**: `import numpy as np`
# - **Example Usage**: `np.where(condition, value_if_true, value_if_false)` is used to generate trading signals based on momentum indicators.
#
# ### <span style="color:#d62728">1.3. Matplotlib</span>
#
# - **Library**: `matplotlib.pyplot`
# - **Purpose**: Provides tools for creating static, animated, and interactive visualizations in Python. It is used to plot various types of graphs and charts to visualize data trends and patterns.
# - **Function**: `import matplotlib.pyplot as plt`
# - **Example Usage**: `plt.plot(x, y)` creates line plots to visualize price trends over time.
#
# ### <span style="color:#9467bd">1.4. Seaborn</span>
#
# - **Library**: `seaborn`
# - **Purpose**: Built on top of Matplotlib, Seaborn provides a high-level interface for drawing attractive and informative statistical graphics. It simplifies the creation of complex visualizations and enhances Matplotlib's capabilities.
# - **Function**: `import seaborn as sns`
# - **Example Usage**: `sns.histplot(data, kde=True)` creates histograms with kernel density estimates to visualize the distribution of data.
#
# ### <span style="color:#8c564b">1.5. Scikit-Learn</span>
#
# - **Library**: `sklearn.preprocessing.StandardScaler`
# - **Purpose**: Provides tools for data preprocessing and machine learning model building. The StandardScaler is used to standardize features by removing the mean and scaling to unit variance, which is crucial for ensuring that all features contribute equally to model performance.
# - **Function**: `from sklearn.preprocessing import StandardScaler`
# - **Example Usage**: `scaler.fit_transform(data)` scales the numerical features of the dataset to have zero mean and unit variance.
#
# Each library is integral to different stages of the data analysis workflow, from data handling and preprocessing to visualization and model building.

# %%
import pandas as pd  # Import pandas for data manipulation

# %%
import numpy as np  # Import numpy for numerical operations

# %%
import matplotlib.pyplot as plt  # Import matplotlib for plotting graphs

# %%
import seaborn as sns  # Import seaborn for advanced data visualization

# %%
from sklearn.preprocessing import StandardScaler  # Import StandardScaler for feature scaling

# %% [markdown]
# ## <span style="color:#1f77b4">1. Data Loading and Exploration</span>
#
# ### <span style="color:#ff7f0e">1.1. Data Loading</span>
#
# - **Objective**: Import the cryptocurrency dataset to start the analysis.
# - **Method**: Use the `pandas` library to load the CSV file into a DataFrame.
# - **Details**:
#   - Ensure the file path is correctly specified.
#   - Load the data into a DataFrame for further exploration.
#
# ### <span style="color:#2ca02c">1.2. Initial Exploration</span>
#
# - **Objective**: Understand the basic structure and contents of the dataset.
# - **Actions**:
#   - **Display First Few Rows**: Use `df.head()` to view the first few rows of the dataset to get an initial sense of the data structure and sample values.
#   - **Summary Statistics**: Use `df.describe()` to obtain summary statistics for numerical columns. This includes mean, median, minimum, maximum, and standard deviation.
#
# ### <span style="color:#d62728">1.3. Check for Missing Values</span>
#
# - **Objective**: Ensure data integrity by identifying and addressing any missing values in the dataset.
# - **Actions**:
#   - **Count Missing Values**: Use `df.isnull().sum()` to count the number of missing values in each column.
#   - **Address Missing Values**: Decide on an approach to handle missing values, such as filling them with a specific value or removing rows/columns with missing data.
#
# ### <span style="color:#9467bd">1.4. Data Types and Conversion</span>
#
# - **Objective**: Ensure data types are appropriate for analysis and convert them if necessary.
# - **Actions**:
#   - **Check Data Types**: Use `df.dtypes` to check the data types of each column.
#   - **Convert Data Types**: Convert columns to appropriate data types if needed. For example, convert the 'Date' column to `datetime` format to facilitate time-series analysis.
#
# ### <span style="color:#8c564b">1.5. Data Integrity Check</span>
#
# - **Objective**: Verify the accuracy and completeness of the data after initial loading and exploration.
# - **Actions**:
#   - **Check for Duplicates**: Use `df.duplicated().sum()` to check for any duplicate rows in the dataset.
#   - **Ensure No Anomalies**: Validate that the data follows expected patterns and ranges. For example, prices should be non-negative and dates should fall within a reasonable range.

# %%
# Load the dataset

# %%
file_path = "/content/coin_CryptocomCoin.csv"  # Path to the dataset

# %%
data = pd.read_csv(file_path)  # Read the CSV file into a DataFrame

# %%
# Display the first few rows of the dataset

# %%
print("First few rows of the dataset:")  # Print header for the first few rows
print(data.head())  # Print the first few rows of the dataset
# Out:
# First few rows of the dataset:
#    SNo             Name Symbol                 Date      High       Low  \
# 0    1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.019845  0.016150
# 1    2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.017496  0.014127
# 2    3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.016723  0.011487
# 3    4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.017215  0.013553
# 4    5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.031509  0.015609
#
#        Open     Close        Volume     Marketcap
# 0  0.019542  0.017243  9.897096e+05  0.000000e+00
# 1  0.017213  0.015301  7.171740e+05  0.000000e+00
# 2  0.015186  0.014448  6.156226e+05  1.547062e+07
# 3  0.014308  0.016260  7.644745e+05  1.785590e+07
# 4  0.016087  0.020790  1.025196e+06  2.340088e+07

# %%
# Display the summary of the dataset

# %%
print("\nSummary of the dataset:")  # Print header for summary statistics
print(data.describe())  # Print summary statistics of the dataset
# Out:
# Summary of the dataset:
#              SNo        High         Low        Open       Close  \
# count  935.00000  935.000000  935.000000  935.000000  935.000000
# mean   468.00000    0.085467    0.078565    0.081802    0.081912
# std    270.05555    0.055912    0.051567    0.053707    0.053693
# min      1.00000    0.012463    0.011487    0.012164    0.012133
# 25%    234.50000    0.042306    0.039469    0.040979    0.041072
# 50%    468.00000    0.068313    0.062851    0.065295    0.065431
# 75%    701.50000    0.121664    0.112010    0.115961    0.116189
# max    935.00000    0.270960    0.234816    0.246416    0.246848
#
#              Volume     Marketcap
# count  9.350000e+02  9.350000e+02
# mean   5.003678e+07  1.485326e+09
# std    9.611248e+07  1.456005e+09
# min    7.388051e+04  0.000000e+00
# 25%    5.441613e+06  4.003142e+08
# 50%    1.699123e+07  7.591310e+08
# 75%    6.591552e+07  2.549040e+09
# max    1.993686e+09  6.236131e+09

# %%
# Check for missing values

# %%
print("\nMissing values in each column:")  # Print header for missing values
print(data.isnull().sum())  # Print the count of missing values in each column
# Out:
# Missing values in each column:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
# Check the data types of each column

# %%
print("Data types of each column:")
print(data.dtypes)  # Print the data types of each column
# Out:
# Data types of each column:
# Date            datetime64[ns]
# High                   float64
# Low                    float64
# Open                   float64
# Close                  float64
# Volume                 float64
# Marketcap              float64
# Year                     int32
# Month                    int32
# Day                      int32
# Momentum_90            float64
# Momentum_180           float64
# Momentum_270           float64
# Momentum_360           float64
# Signal_90                int64
# Signal_180               int64
# Signal_270               int64
# Signal_360               int64
# EMA_12                 float64
# EMA_26                 float64
# MACD                   float64
# Signal                 float64
# dtype: object

# %%
# Check for duplicate rows

# %%
duplicates = data.duplicated().sum()  # Count the number of duplicate rows

# %%
print(f"Number of duplicate rows: {duplicates}")  # Print the count of duplicate rows
# Out:
# Number of duplicate rows: 0

# %%
# Check for anomalies

# %%
if 'Price' in data.columns:  # Check if 'Price' column exists
    negative_prices = data[data['Price'] < 0].shape[0]  # Count the number of rows with negative prices
    print(f"Number of rows with negative prices: {negative_prices}")  # Print the count of rows with negative prices

# %%
if 'Date' in data.columns:  # Check if 'Date' column exists
    date_range = data['Date'].min(), data['Date'].max()  # Get the date range in the 'Date' column
    print(f"Date range: {date_range}")  # Print the date range
# Out:
# Date range: (Timestamp('2018-12-15 23:59:59'), Timestamp('2021-07-06 23:59:59'))

# %% [markdown]
# ## <span style="color:#1f77b4">2. Data Preprocessing and Feature Engineering</span>
#
# ### <span style="color:#ff7f0e">2.1. Date Conversion</span>
#
# - **Objective**: Prepare the dataset for time-series analysis by converting date-related columns to appropriate formats.
# - **Actions**:
#   - **Convert 'Date' Column**: Convert the 'Date' column from string format to `datetime` format using `pd.to_datetime()`. This enables easy extraction of time-based features and ensures proper handling of date operations.
#
# ### <span style="color:#2ca02c">2.2. Feature Extraction from Date</span>
#
# - **Objective**: Enhance the dataset with additional time-based features that can be useful for analysis and modeling.
# - **Actions**:
#   - **Extract Year, Month, and Day**: Create new columns for year, month, and day by extracting these components from the 'Date' column. This can help in analyzing trends over different time periods (e.g., yearly, monthly, daily).
#
# ### <span style="color:#d62728">2.3. Handling Missing Values</span>
#
# - **Objective**: Address any missing values that may have been present in the dataset to ensure completeness and reliability.
# - **Actions**:
#   - **Identify Missing Values**: Use `df.isnull().sum()` to identify columns with missing values.
#   - **Impute or Drop Missing Values**: Depending on the extent and nature of the missing values, decide whether to fill them with a specific value (e.g., mean, median) or to drop rows/columns containing missing values.
#
# ### <span style="color:#9467bd">2.4. Removing Irrelevant Columns</span>
#
# - **Objective**: Streamline the dataset by removing columns that are not needed for the analysis.
# - **Actions**:
#   - **Drop Columns**: Use `df.drop(columns=['Column1', 'Column2'])` to remove columns that do not contribute to the analysis. This helps in reducing noise and improving the efficiency of subsequent processing steps.
#
# ### <span style="color:#8c564b">2.5. Encoding Categorical Variables</span>
#
# - **Objective**: Prepare the dataset for machine learning models by encoding categorical variables into numerical formats if needed.
# - **Actions**:
#   - **Check for Categorical Variables**: Identify any categorical columns using `df.select_dtypes(include=['object'])`.
#   - **Apply Encoding**: If categorical variables are present, apply encoding techniques such as one-hot encoding or label encoding to convert them into numerical formats.
#
# ### <span style="color:#e377c2">2.6. Outlier Detection and Removal</span>
#
# - **Objective**: Improve the robustness of the analysis by detecting and handling outliers in the dataset.
# - **Actions**:
#   - **Identify Outliers**: Use methods like the Interquartile Range (IQR) to detect outliers in numerical columns.
#   - **Remove Outliers**: Implement a function to remove outliers based on the calculated IQR thresholds. This ensures that extreme values do not skew the analysis.
#
# ### <span style="color:#7f7f7f">2.7. Feature Scaling</span>
#
# - **Objective**: Normalize the range of numerical features to ensure fair contribution to model training and analysis.
# - **Actions**:
#   - **Apply Scaling**: Use `StandardScaler` to scale numerical features to a standard range (e.g., mean = 0, variance = 1). This is crucial for algorithms sensitive to feature scales, such as clustering or regression models.

# %%
# Convert the 'Date' column to datetime format

# %%
data['Date'] = pd.to_datetime(data['Date'])  # Convert 'Date' column to datetime format

# %%
# Extract date features

# %%
data['Year'] = data['Date'].dt.year  # Extract year from 'Date' column

# %%
data['Month'] = data['Date'].dt.month  # Extract month from 'Date' column

# %%
data['Day'] = data['Date'].dt.day  # Extract day from 'Date' column

# %% [markdown]
# ## <span style="color:#1f77b4">3. Data Visualization</span>
#
# ### <span style="color:#ff7f0e">3.1. Plot of High and Low Prices Over Time</span>
#
# - **Objective**: Visualize the fluctuation in high and low prices to understand trends and price volatility.
# - **Actions**:
#   - **Create Line Plot**: Use `plt.plot()` to create a line plot of high and low prices over time. Set distinct colors and labels for each price type to enhance clarity.
#   - **Enhance Plot**: Add a title, x-axis label, y-axis label, and legend to make the plot informative and easy to interpret.
#
# ### <span style="color:#2ca02c">3.2. Volume of Trades Over Time</span>
#
# - **Objective**: Examine the trading volume to identify trends, peaks, and troughs in trading activity.
# - **Actions**:
#   - **Create Line Plot**: Use `plt.plot()` to visualize the volume of trades over time. Differentiate the volume line with a unique color.
#   - **Enhance Plot**: Include title, x-axis label, y-axis label, and legend to ensure the plot conveys clear information.
#
# ### <span style="color:#d62728">3.3. Market Capitalization Over Time</span>
#
# - **Objective**: Analyze the market capitalization over time to assess growth or contraction in the market value of the cryptocurrency.
# - **Actions**:
#   - **Create Line Plot**: Utilize `plt.plot()` to plot market capitalization over time. Choose a distinct color for the market cap line.
#   - **Enhance Plot**: Add relevant titles, axis labels, and a legend to provide context and improve readability.
#
# ### <span style="color:#9467bd">3.4. Distribution of 'Close' Prices</span>
#
# - **Objective**: Understand the distribution of closing prices to analyze price trends and detect potential anomalies.
# - **Actions**:
#   - **Create Histogram**: Use `sns.histplot()` to create a histogram of closing prices. Overlay a Kernel Density Estimate (KDE) for a smoothed representation.
#   - **Enhance Plot**: Add a title to the histogram to indicate what is being represented and ensure that the plot is easily interpretable.
#
# ### <span style="color:#8c564b">3.5. Close Price Over Time</span>
#
# - **Objective**: Visualize the closing price trends over time to identify patterns and long-term movements.
# - **Actions**:
#   - **Create Line Plot**: Use `plt.plot()` to display closing prices over time.
#   - **Enhance Plot**: Add a descriptive title, x-axis label, and y-axis label to make the plot informative and clear.
#
# ### <span style="color:#e377c2">3.6. Correlation Heatmap</span>
#
# - **Objective**: Explore the relationships between different numerical features to understand their correlations and potential multicollinearity.
# - **Actions**:
#   - **Create Heatmap**: Use `sns.heatmap()` to visualize the correlation matrix of the features. Annotate the heatmap to display correlation coefficients.
#   - **Enhance Plot**: Set a title and use a color map that effectively represents correlation values to make the heatmap easy to interpret.

# %%
# Plot of High and Low Prices Over Time

# %%
plt.figure(figsize=(14, 7))  # Set figure size for the plot
plt.plot(data['Date'], data['High'], label='High Price', color='green')  # Plot 'High' prices
plt.plot(data['Date'], data['Low'], label='Low Price', color='red')  # Plot 'Low' prices
plt.title('High and Low Prices Over Time')  # Set the title of the plot
plt.xlabel('Date')  # Set the x-axis label
plt.ylabel('Price')  # Set the y-axis label
plt.legend()  # Show legend
plt.show()  # Display the plot

# %%
# Volume of Trades Over Time

# %%
plt.figure(figsize=(14, 7))  # Set figure size for the plot
plt.plot(data['Date'], data['Volume'], label='Volume', color='blue')  # Plot trading volume
plt.title('Volume of Trades Over Time')  # Set the title of the plot
plt.xlabel('Date')  # Set the x-axis label
plt.ylabel('Volume')  # Set the y-axis label
plt.legend()  # Show legend
plt.show()  # Display the plot

# %%
# Market Capitalization Over Time

# %%
plt.figure(figsize=(14, 7))  # Set figure size for the plot
plt.plot(data['Date'], data['Marketcap'], label='Market Capitalization', color='purple')  # Plot market capitalization
plt.title('Market Capitalization Over Time')  # Set the title of the plot
plt.xlabel('Date')  # Set the x-axis label
plt.ylabel('Market Cap')  # Set the y-axis label
plt.legend()  # Show legend
plt.show()  # Display the plot

# %%
# Drop irrelevant columns

# %%
data = data.drop(columns=['SNo', 'Name', 'Symbol'])  # Drop columns not needed for analysis

# %% [markdown]
# ## <span style="color:#1f77b4">4. Outlier Detection and Handling</span>
#
# ### <span style="color:#ff7f0e">4.1. Outlier Detection Using IQR Method</span>
#
# - **Objective**: Identify and remove outliers in numerical features to ensure the accuracy and reliability of the analysis.
# - **Actions**:
#   - **Define Function**: Create a function `remove_outliers()` that uses the Interquartile Range (IQR) method for outlier detection.
#     - **Calculate Quartiles**: Compute the first quartile (Q1) and the third quartile (Q3) for the given column.
#     - **Compute IQR**: Calculate the IQR by subtracting Q1 from Q3.
#     - **Determine Bounds**: Define the lower and upper bounds for outlier detection as Q1 - 1.5 * IQR and Q3 + 1.5 * IQR, respectively.
#     - **Filter Data**: Return only the rows where the column values are within the calculated bounds.
#   - **Apply Function**: Use the `remove_outliers()` function to process columns of interest: 'High', 'Low', 'Open', 'Close', 'Volume', and 'Marketcap'.
#     - **Iterate Over Columns**: Loop through the specified columns and apply the function to remove outliers.
#
# ### <span style="color:#2ca02c">4.2. Handling Missing Values</span>
#
# - **Objective**: Ensure that missing values are addressed to prevent issues in data analysis.
# - **Actions**:
#   - **Review Missing Values**: Since the dataset does not have missing values (as previously confirmed), no further action is needed for missing values in this case.
#   - **Documentation**: Note that missing values handling is not required in this step due to the absence of missing data.
#
# ### <span style="color:#d62728">4.3. Encoding Categorical Values</span>
#
# - **Objective**: Prepare the data for modeling by encoding categorical variables if any are present.
# - **Actions**:
#   - **Check for Categorical Data**: Since there are no categorical values in this dataset, no encoding is needed.
#   - **Documentation**: Confirm that encoding of categorical values is not necessary for this dataset.

# %%
# Handling missing values

# %%
# In this case, we see that there are no missing values, so no action needed

# %%
# Encoding categorical values

# %%
# No categorical values in this dataset, so no encoding needed

# %%
# Outlier detection and handling

# %%
# We will use IQR method to detect and remove outliers

# %%
def remove_outliers(df, column):  # Define a function to remove outliers using IQR method
    Q1 = df[column].quantile(0.25)  # Calculate the first quartile (25th percentile) of the column
    Q3 = df[column].quantile(0.75)  # Calculate the third quartile (75th percentile) of the column
    IQR = Q3 - Q1  # Calculate the Interquartile Range (IQR)
    lower_bound = Q1 - 1.5 * IQR  # Calculate the lower bound for outlier detection
    upper_bound = Q3 + 1.5 * IQR  # Calculate the upper bound for outlier detection
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]  # Return rows where column values are within bounds

# %%
columns_to_check = ['High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']  # List of columns to check for outliers

# %%
for column in columns_to_check:  # Loop through each column
    data = remove_outliers(data, column)  # Remove outliers from the column

# %% [markdown]
# ## <span style="color:#1f77b4">5. Scaling Numerical Values</span>
#
# ### <span style="color:#ff7f0e">5.1. Feature Scaling Using StandardScaler</span>
#
# - **Objective**: Normalize the numerical features to ensure that all features contribute equally to the analysis and model performance.
# - **Actions**:
#   - **Initialize StandardScaler**: Create an instance of `StandardScaler` from scikit-learn.
#   - **Apply Scaling**: Use the `fit_transform()` method of `StandardScaler` to scale the following numerical columns:
#     - 'High'
#     - 'Low'
#     - 'Open'
#     - 'Close'
#     - 'Volume'
#     - 'Marketcap'
#   - **Scaling Process**:
#     - **Fit**: Compute the mean and standard deviation of each column.
#     - **Transform**: Standardize the columns by subtracting the mean and dividing by the standard deviation.
#   - **Update Data**: Replace the original columns in the DataFrame with the scaled values.
#
# ### <span style="color:#2ca02c">5.2. Impact of Scaling on Analysis</span>
#
# - **Objective**: Understand the effect of feature scaling on the data and subsequent analyses.
# - **Actions**:
#   - **Review Scaled Data**: Check the scaled values to ensure they are standardized correctly.
#   - **Documentation**: Note that scaling helps to bring all numerical features to a common scale, which is crucial for many statistical analyses and machine learning algorithms.

# %%
# Scaling numerical values

# %%
scaler = StandardScaler()  # Initialize the StandardScaler

# %%
data[['High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']] = scaler.fit_transform(data[['High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']])  # Scale numerical features

# %% [markdown]
# ## <span style="color:#1f77b4">6. Visualizations</span>
#
# ### <span style="color:#ff7f0e">6.1. Distribution of 'Close' Prices</span>
#
# - **Objective**: Analyze the distribution of the 'Close' prices to understand their frequency and overall distribution pattern.
# - **Actions**:
#   - **Plot Histogram**: Create a histogram with Kernel Density Estimate (KDE) to visualize the distribution of 'Close' prices.
#     - **Histogram**: Shows the frequency of different price ranges.
#     - **KDE**: Provides a smooth estimate of the probability density function.
#   - **Interpretation**: Review the histogram to identify the shape of the distribution, any potential skewness, or concentration of values.
#
# ### <span style="color:#2ca02c">6.2. Close Price Over Time</span>
#
# - **Objective**: Examine how 'Close' prices have changed over time to identify trends and patterns.
# - **Actions**:
#   - **Plot Line Graph**: Create a line plot of 'Close' prices against the 'Date' to visualize changes over time.
#     - **X-Axis**: Date
#     - **Y-Axis**: Close Price
#   - **Interpretation**: Observe trends, fluctuations, and potential seasonality in the 'Close' prices. Look for any noticeable upward or downward trends.
#
# ### <span style="color:#d62728">6.3. Correlation Heatmap</span>
#
# - **Objective**: Understand the relationships between different numerical features in the dataset.
# - **Actions**:
#   - **Plot Heatmap**: Generate a heatmap showing the correlation coefficients between numerical features.
#     - **Correlation Coefficient**: Indicates the strength and direction of the linear relationship between pairs of features.
#   - **Interpretation**: Analyze the heatmap to identify strong correlations, potential multicollinearity issues, and relationships that could impact further analysis or modeling.

# %%
# Visualizations

# %%
# Distribution of 'Close' prices

# %%
plt.figure(figsize=(10, 6))  # Set figure size for the plot
sns.histplot(data['Close'], kde=True)  # Plot the histogram of 'Close' prices with KDE
plt.title('Distribution of Close Prices')  # Set the title of the plot
plt.show()  # Display the plot

# %%
# Close price over time

# %%
plt.figure(figsize=(14, 7))  # Set figure size for the plot
plt.plot(data['Date'], data['Close'])  # Plot 'Close' prices over time
plt.title('Close Price Over Time')  # Set the title of the plot
plt.xlabel('Date')  # Set the x-axis label
plt.ylabel('Close Price')  # Set the y-axis label
plt.show()  # Display the plot

# %%
# Correlation heatmap

# %%
plt.figure(figsize=(10, 6))  # Set figure size for the plot
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')  # Plot heatmap of feature correlations
plt.title('Correlation Heatmap')  # Set the title of the plot
plt.show()  # Display the plot

# %% [markdown]
# ## <span style="color:#1f77b4">7. Momentum Trading Strategy</span>
#
# ### <span style="color:#ff7f0e">7.1. Calculating Momentum Indicators</span>
#
# - **Objective**: Compute momentum indicators to identify potential buy and sell signals based on historical price changes.
# - **Actions**:
#   - **Define Momentum Calculation**: Create a function to calculate momentum based on past returns.
#     - **Function**: `calculate_momentum(data, period)` calculates the difference in 'Close' prices over a specified period.
#   - **Apply Function**: Calculate momentum indicators for various periods (90, 180, 270, 360 days) and add these as new columns in the dataset.
#     - **Periods**: Define different time periods to capture various momentum signals.
#   - **Result**: Generate new columns in the dataset representing momentum values for each period.
#
# ### <span style="color:#2ca02c">7.2. Distribution of Momentum Indicators</span>
#
# - **Objective**: Analyze the distribution of momentum indicators to understand their frequency and distribution patterns.
# - **Actions**:
#   - **Plot Histograms**: Create histograms with KDE for momentum indicators calculated for each period.
#     - **Histograms**: Show the distribution of momentum values.
#     - **KDE**: Provides a smooth estimate of the distribution.
#   - **Interpretation**: Examine the histograms to identify the distribution of momentum values, their concentration, and any potential outliers.
#
# ### <span style="color:#d62728">7.3. Generating Buy and Sell Signals</span>
#
# - **Objective**: Generate trading signals based on the computed momentum indicators to implement a trading strategy.
# - **Actions**:
#   - **Define Signal Generation**: Create new columns in the dataset to represent buy and sell signals based on momentum values.
#     - **Signal Criteria**: Assign a value of `1` for buy signals and `-1` for sell signals if the momentum is positive or negative, respectively.
#   - **Apply Signal Generation**: Compute signals for each period and add them as new columns in the dataset.
#   - **Result**: The dataset now includes columns representing buy and sell signals based on the defined criteria.
#
# ### <span style="color:#9467bd">7.4. Plotting Buy and Sell Signals</span>
#
# - **Objective**: Visualize buy and sell signals to assess the effectiveness of the momentum trading strategy.
# - **Actions**:
#   - **Plot Signals**: Create a line plot showing 'Close' prices along with buy and sell signals for a selected period (e.g., 90 days).
#     - **Buy Signals**: Represented by upward-pointing triangles.
#     - **Sell Signals**: Represented by downward-pointing triangles.
#   - **Interpretation**: Review the plot to evaluate the performance of the trading strategy and the alignment of signals with price movements.

# %%
# Momentum Trading Strategy

# %%
# Calculate the Momentum Indicator (past 3 to 12 months returns)

# %%
def calculate_momentum(data, period):  # Define a function to calculate momentum
    return data['Close'].diff(period)  # Calculate the difference in 'Close' prices over the specified period

# %%
# Adding momentum columns for 3, 6, 9, and 12 months (90, 180, 270, 360 days)

# %%
periods = [90, 180, 270, 360]  # List of periods for momentum calculation

# %%
for period in periods:  # Loop through each period
    data[f'Momentum_{period}'] = calculate_momentum(data, period)  # Calculate and add momentum column for the period

# %%
# Momentum Indicator Distribution

# %%
plt.figure(figsize=(14, 7))  # Set figure size for the plot
for period in periods:  # Loop through each period
    sns.histplot(data[f'Momentum_{period}'], kde=True, label=f'Momentum {period} days')  # Plot histogram of momentum indicators
plt.title('Distribution of Momentum Indicators')  # Set the title of the plot
plt.xlabel('Momentum')  # Set the x-axis label
plt.ylabel('Frequency')  # Set the y-axis label
plt.legend()  # Show legend
plt.show()  # Display the plot

# %%
# Strategy: Buy if momentum is positive, sell if momentum is negative

# %%
for period in periods:  # Loop through each period
    data[f'Signal_{period}'] = np.where(data[f'Momentum_{period}'] > 0, 1, -1)  # Generate buy (1) and sell (-1) signals based on momentum

# %%
# Plotting the buy and sell signals for a selected period (e.g., 3 months)

# %%
selected_period = 90  # Define the selected period for plotting
plt.figure(figsize=(14, 7))  # Set figure size for the plot
plt.plot(data['Date'], data['Close'], label='Close Price')  # Plot 'Close' prices
plt.plot(data[data[f'Signal_{selected_period}'] == 1]['Date'], data[data[f'Signal_{selected_period}'] == 1]['Close'], '^', markersize=10, color='g', alpha=0.7, label='Buy Signal')  # Plot buy signals
plt.plot(data[data[f'Signal_{selected_period}'] == -1]['Date'], data[data[f'Signal_{selected_period}'] == -1]['Close'], 'v', markersize=10, color='r', alpha=0.7, label='Sell Signal')  # Plot sell signals
plt.title(f'Momentum Trading Strategy Buy and Sell Signals (Period: {selected_period} days)')  # Set the title of the plot
plt.xlabel('Date')  # Set the x-axis label
plt.ylabel('Close Price')  # Set the y-axis label
plt.legend()  # Show legend
plt.show()  # Display the plot

# %% [markdown]
# ## <span style="color:#1f77b4">8. Calculating MACD (Moving Average Convergence Divergence)</span>
#
# ### <span style="color:#ff7f0e">8.1. Introduction to MACD</span>
#
# - **Objective**: Calculate the MACD (Moving Average Convergence Divergence) to further enhance trading signals.
# - **Description**: The MACD is a trend-following momentum indicator that shows the relationship between two moving averages of a security's price. It consists of:
#   - **MACD Line**: Difference between the 12-day EMA (Exponential Moving Average) and the 26-day EMA.
#   - **Signal Line**: 9-day EMA of the MACD Line.
#   - **Histogram**: Difference between the MACD Line and the Signal Line.
#
# ### <span style="color:#2ca02c">8.2. Calculating MACD Components</span>
#
# - **Objective**: Compute the MACD line and Signal line to analyze trend and momentum.
# - **Actions**:
#   - **Calculate EMAs**: Compute the 12-day and 26-day EMAs of the 'Close' price.
#     - **12-day EMA**: `data['EMA_12'] = data['Close'].ewm(span=12, adjust=False).mean()`
#     - **26-day EMA**: `data['EMA_26'] = data['Close'].ewm(span=26, adjust=False).mean()`
#   - **Compute MACD Line**: Subtract the 26-day EMA from the 12-day EMA.
#     - **Formula**: `data['MACD'] = data['EMA_12'] - data['EMA_26']`
#   - **Calculate Signal Line**: Compute the 9-day EMA of the MACD Line.
#     - **Formula**: `data['Signal'] = data['MACD'].ewm(span=9, adjust=False).mean()`
#
# ### <span style="color:#d62728">8.3. Plotting MACD and Signal Line</span>
#
# - **Objective**: Visualize the MACD Line and Signal Line to identify potential trading signals.
# - **Actions**:
#   - **Plot Lines**: Create a line plot to show the MACD Line and Signal Line over time.
#     - **MACD Line**: Plotted in blue.
#     - **Signal Line**: Plotted in red.
#   - **Title and Labels**: Add titles and labels to the plot for clarity.
#     - **Title**: "MACD and Signal Line"
#     - **X-axis**: 'Date'
#     - **Y-axis**: 'Value'
#   - **Interpretation**: Analyze the plot to identify crossovers and trends:
#     - **Buy Signal**: When the MACD Line crosses above the Signal Line.
#     - **Sell Signal**: When the MACD Line crosses below the Signal Line.

# %%
# Calculate MACD

# %%
data['EMA_12'] = data['Close'].ewm(span=12, adjust=False).mean()  # Calculate the 12-day EMA

# %%
data['EMA_26'] = data['Close'].ewm(span=26, adjust=False).mean()  # Calculate the 26-day EMA

# %%
data['MACD'] = data['EMA_12'] - data['EMA_26']  # Calculate MACD line

# %%
data['Signal'] = data['MACD'].ewm(span=9, adjust=False).mean()  # Calculate Signal line

# %%
# Plot MACD and Signal Line

# %%
plt.figure(figsize=(14, 7))  # Set figure size for the plot
plt.plot(data['Date'], data['MACD'], label='MACD', color='blue')  # Plot MACD line
plt.plot(data['Date'], data['Signal'], label='Signal Line', color='red')  # Plot Signal line
plt.title('MACD and Signal Line')  # Set the title of the plot
plt.xlabel('Date')  # Set the x-axis label
plt.ylabel('Value')  # Set the y-axis label
plt.legend()  # Show legend
plt.show()  # Display the plot

# %% [markdown]
# ## <span style="color:#1f77b4">9. Displaying Final Dataset with Signals</span>
#
# ### <span style="color:#ff7f0e">9.1. Objective</span>
#
# - **Purpose**: Review the final dataset after adding momentum indicators and trading signals.
# - **Goal**: Ensure all computed indicators and signals are correctly added and inspect the first few rows of the final dataset.
#
# ### <span style="color:#2ca02c">9.2. Displaying the Dataset</span>
#
# - **Objective**: Print the first few rows of the dataset to verify the inclusion of new columns and check the accuracy of the calculations.
# - **Actions**:
#   - **Print Dataset**: Use `data.head()` to display the initial rows of the dataset.
#     - **Purpose**: Verify the correct addition of momentum indicators and signals for trading decisions.
#     - **Review Columns**: Ensure that columns such as 'Momentum_90', 'Momentum_180', 'Momentum_270', 'Momentum_360', 'Signal_90', 'Signal_180', 'Signal_270', 'Signal_360', 'EMA_12', 'EMA_26', 'MACD', and 'Signal' are present.
#
# ### <span style="color:#d62728">9.3. Interpretation</span>
#
# - **Objective**: Analyze the final dataset to understand the effect of added indicators and signals on trading strategy.
# - **Actions**:
#   - **Check Indicators**: Review the calculated momentum values and MACD indicators.
#   - **Verify Signals**: Confirm that the buy and sell signals align with the computed momentum and MACD values.
#   - **Analyze Data**: Use this dataset to make informed decisions or perform further analysis based on the calculated indicators.
#
# ### <span style="color:#1f77b4">9.4. Next Steps</span>
#
# - **Save Dataset**: Export the final dataset to a CSV file for future reference or additional analysis.
#   - **File Path**: `'/content/momentum_trading_strategy.csv'`
#   - **Action**: Save the dataset using `data.to_csv()` to preserve the results of the analysis.

# %%
# Display final dataset with signals

# %%
print("\nDataset with Momentum and Signals:")  # Print header for final dataset
print(data.head())  # Print the first few rows of the dataset with momentum and signals
# Out:
# Dataset with Momentum and Signals:
#                  Date      High       Low      Open     Close    Volume  \
# 0 2018-12-15 23:59:59 -1.238936 -1.255472 -1.205239 -1.264309 -0.890888
# 1 2018-12-16 23:59:59 -1.292366 -1.303672 -1.259367 -1.309679 -0.899180
# 2 2018-12-17 23:59:59 -1.309964 -1.366597 -1.306456 -1.329591 -0.902270
# 3 2018-12-18 23:59:59 -1.298764 -1.317358 -1.326859 -1.287283 -0.897741
# 4 2018-12-19 23:59:59 -0.973578 -1.268371 -1.285537 -1.181476 -0.889809
#
#    Marketcap  Year  Month  Day  ...  Momentum_270  Momentum_360  Signal_90  \
# 0  -1.093497  2018     12   15  ...           NaN           NaN         -1
# 1  -1.093497  2018     12   16  ...           NaN           NaN         -1
# 2  -1.078981  2018     12   17  ...           NaN           NaN         -1
# 3  -1.076743  2018     12   18  ...           NaN           NaN         -1
# 4  -1.071541  2018     12   19  ...           NaN           NaN         -1
#
# ...

# %%
# Save the final dataset to CSV

# %%
data.to_csv('/content/momentum_trading_strategy.csv', index=False)  # Save the final dataset with momentum and signals to a CSV file

# %% [markdown]
# ## <span style="color:#1f77b4">10. Conclusions</span>
#
# ### <span style="color:#ff7f0e">10.1. Summary of Findings</span>
#
# - **Data Insights**:
#   - The **Momentum Indicators** provide valuable insights into price trends over different periods, reflecting the price momentum and potential trading opportunities.
#   - **MACD** (Moving Average Convergence Divergence) and its **Signal Line** offer a comprehensive view of the trend strength and direction, which are crucial for making informed trading decisions.
#
# - **Trading Signals**:
#   - The **Buy and Sell Signals** generated based on momentum indicators and MACD values help in identifying potential entry and exit points for trades.
#   - The signals indicate **buy** opportunities when momentum is positive and **sell** opportunities when momentum is negative, guiding trading strategies effectively.
#
# ### <span style="color:#2ca02c">10.2. Effectiveness of the Momentum Strategy</span>
#
# - **Strategy Performance**:
#   - The momentum trading strategy using various periods (3, 6, 9, and 12 months) and MACD successfully highlights potential trading signals based on historical price movements.
#   - The effectiveness of the strategy can be further evaluated by backtesting it against historical data to measure its profitability and reliability.
#
# - **Visualization**:
#   - The visualizations, including **price trends**, **volume of trades**, **market capitalization**, and **momentum distributions**, provide a clear understanding of market behavior and trading signals.
#   - The **MACD and Signal Line** plot visually demonstrates the alignment and divergences between the MACD and Signal Line, aiding in trend analysis.
#
# ### <span style="color:#d62728">10.3. Recommendations</span>
#
# - **Further Analysis**:
#   - Perform backtesting of the trading strategy to validate its effectiveness and refine the approach based on historical performance.
#   - Investigate other technical indicators and combine them with momentum analysis to enhance the trading strategy.
#
# - **Optimization**:
#   - Optimize the strategy parameters (e.g., periods for momentum calculations) based on empirical results to improve trading performance.
#   - Consider incorporating additional market data or features to enhance the robustness of the trading signals.
#
# - **Documentation**:
#   - Document the findings, methodology, and results comprehensively to facilitate future reference and potential improvements.
#   - Share insights and recommendations with stakeholders or within trading communities to contribute to collective knowledge and strategy development.
#
# ### <span style="color:#1f77b4">10.4. Future Work</span>
#
# - **Enhanced Models**:
#   - Explore advanced models and machine learning algorithms to predict market movements and refine trading signals.
#   - Develop and test automated trading systems based on the momentum strategy and MACD indicators for real-time trading applications.
#
# - **Integration**:
#   - Integrate the momentum trading strategy with trading platforms or financial analysis tools to apply insights directly in trading environments.
#   - Collaborate with financial analysts and traders to validate and adapt the strategy for different market conditions and assets.
